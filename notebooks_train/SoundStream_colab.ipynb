# %%
# !git clone -b soundstream-gan-extra https://github.com/DommeUse/pytorch_project_template.git
# %cd pytorch_project_template
# Out:
# Cloning into 'pytorch_project_template'...
# remote: Enumerating objects: 844, done.
# remote: Counting objects: 100% (291/291), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 844 (delta 172), reused 184 (delta 82), pack-reused 553 (from 2)
# Receiving objects: 100% (844/844), 1.09 MiB | 19.17 MiB/s, done.
# Resolving deltas: 100% (443/443), done.
# /content/pytorch_project_template

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.0/787.0 kB 61.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 kB 28.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 97.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 13.2 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

os.environ["COMET_API_KEY"] = userdata.get('COMET_API_KEY')

# %% [markdown]
# ### $l_{adv}$ = 2.5

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_rec_attention"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/57p8mhgpmttqate2b7dvo0ouzkrz65ah
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:29<00:00, 972.00it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11484.57it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (1): ELU(alpha=1.0)
# ...

# %%
import comet_ml

api = comet_ml.API(api_key=userdata.get('COMET_API_KEY'))
exp = api.get_experiment("german-zverev", "soundstream", "57p8mhgpmttqate2b7dvo0ouzkrz65ah")

assets = exp.get_asset_list()
print(assets)
model_asset = [a for a in assets if "model" in a['fileName']]
asset_id = model_asset[0]['assetId']
asset_binary = exp.get_asset(asset_id)

with open("./model_best.pth", "wb") as f:
    f.write(asset_binary)
# Out:
# [{'fileName': 'train/reconstructed_train', 'fileSize': 16044, 'runContext': None, 'step': 18500, 'remote': False, 'link': 'https://www.comet.com/api/asset/download?experimentKey=57p8mhgpmttqate2b7dvo0ouzkrz65ah&assetId=004554457e864e898be78d0f8fbe6eda&isCompressed=false', 'compressedAssetLink': 'https://www.comet.com/api/asset/download?experimentKey=57p8mhgpmttqate2b7dvo0ouzkrz65ah&assetId=004554457e864e898be78d0f8fbe6eda&isCompressed=true', 's3Link': 'https://s3.amazonaws.com/comet.ml/asset_audio-57p8mhgpmttqate2b7dvo0ouzkrz65ah-wRG3UMXpFnALQw2ay4d8kuCKF.?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20260513T104000Z&X-Amz-SignedHeaders=host&X-Amz-Expires=900&X-Amz-Credential=AKIAJNHSS5T6JUKPCRJQ%2F20260513%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=479a8d0ff6e690667de3b076f7ef18cc7a6b9ecb3d9647a4c8c69db7dccb5e41', 'createdAt': 1778548458904, 'dir': 'audio', 'canView': False, 'audio': True, 'video': False, 'histogram': False, 'image': False, 'type': 'audio', 'metadata': '{"sample
# ...

# %%
import torch

checkpoint = torch.load("./model_best.pth", "cuda", weights_only = False)
checkpoint['config']['writer']['run_id'] = '57p8mhgpmttqate2b7dvo0ouzkrz65ah'
torch.save(checkpoint, './model_best.pth')

# %%
checkpoint = torch.load("./model_best.pth", "cuda", weights_only = False)

# %%
checkpoint['config']['writer']['run_id']
# Out:
# '57p8mhgpmttqate2b7dvo0ouzkrz65ah'

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    +writer.run_id="57p8mhgpmttqate2b7dvo0ouzkrz65ah" \
    trainer.resume_from="./model_best.pth"
# Out:
# Resuming training from run alu3wol6r97jimwdbqf28jnlg7n2ydk4...
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/57p8mhgpmttqate2b7dvo0ouzkrz65ah
#
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (1): ELU(alpha=1.0)
#               (2): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#               )
#             )
#           )
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_final_run"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/ouc7i3ratse556o3tuqo37trpoy98nqy
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11663.26it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11521.94it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (1): ELU(alpha=1.0)
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_alphas"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/p7636psxa11kly4roobfv9tflj0hd0uw
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11495.53it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11602.86it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (1): ELU(alpha=1.0)
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_rvq_fix"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/ldqguksmp4f1zzk11718pnhjuuxqrlob
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11545.87it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11524.32it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (1): ELU(alpha=1.0)
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_codebook_fix"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/teaanr4tbk8pln0qmkk27fgs5gqmhue8
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:04<00:00, 6371.55it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11557.62it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (1): ELU(alpha=1.0)
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_res_blocks_fix"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/u2onkstvrayv4a6qqtluyb43lu4m1235
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11663.77it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11489.72it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_result"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/jy22mjipfasvypx9lvx1v9j6yzpjqrz8
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11382.86it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11184.36it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_hann_window"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/xmhmf00zgxx8zakcdfvzo3r47958m217
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11496.15it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11581.60it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_stoi_fix"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/cc8t70krz6gyvnb76vuyjpx9wap8hi0p
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11324.33it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11470.31it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
  --config-name=soundstream_gan \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="gan_45k_baseline_grad_clip"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/ck7hrs1yjjcnkulqrdut4oq063tusteq
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11340.38it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11687.62it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    writer.log_checkpoints=True \
    writer.run_name="gan_45k_baseline_disc_fix"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/770k0b3jinas3u5ckn8ewjfg20h110hl
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11338.37it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11358.52it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
  --config-name=soundstream_gan \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="gan_45k_baseline_log_alphas"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/i4in7uy4k55rlkbehs93q4jbs2lrjsn0
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11426.00it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11634.94it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %% [markdown]
# ### One of final

# %%
# !python train.py \
  --config-name=soundstream_gan \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="gan_45k_baseline_best_metrics"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/um6cq6pfeupxf57eg3o7ui6yjgyoulnp
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11582.36it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11596.21it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
  --config-name=soundstream_gan \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="gan_45k_baseline_better_stoi"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/of6ankge1776s78f0xnknidswvmgbyeu
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11132.53it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11819.17it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
  --config-name=soundstream \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="recon_only_45k_baseline_better_stoi"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/wh50lbc7m4t7cry8in7ct6ytfgbmxtsd
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11522.99it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11711.66it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %% [markdown]
# ### Reduced

# %%
# !python train.py \
  --config-name=soundstream_gan \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="gan_45k_baseline_reduced"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/1fn2j76oxlff2oclv45qtavignuxpu65
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11452.73it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11759.47it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
  --config-name=soundstream \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="recon_only_45k_baseline_reduced"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/7n0py1hie4a5v59q2hp1j97jr6e02vca
#
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (2): ELU(alpha=1.0)
#               (3): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#             )
#           )
#           (1): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
# ...

# %%
# !python train.py \
  --config-name=soundstream_gan \
  trainer.save_dir="/content/saved" \
  writer.log_checkpoints=True \
  writer.run_name="gan_45k_baseline_extra"
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/9x8wz76ek1nnfj4i7a6pdwcevzacu5yr
#
# Loading split train-clean-100
# Preparing librispeech split train-clean-100: 100% 28539/28539 [00:02<00:00, 11572.47it/s]
# Loading split test-clean
# Preparing librispeech split test-clean: 100% 2620/2620 [00:00<00:00, 11657.25it/s]
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
# ...

# %%
# !python train.py \
    --config-name=soundstream_gan \
    trainer.save_dir="/content/saved" \
    trainer.resume_from="/content/saved/gan_45k_baseline_extra/model_best.pth" \
    trainer.n_epochs=11
# Out:
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/german-zverev/soundstream/9x8wz76ek1nnfj4i7a6pdwcevzacu5yr
#
# SoundStream(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): CausalConv1d(
#         (conv): Conv1d(1, 32, kernel_size=(7,), stride=(1,))
#       )
#       (1): ELU(alpha=1.0)
#       (2): EncoderBlock(
#         (net): Sequential(
#           (0): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
#               (1): CausalConv1d(
#                 (conv): Conv1d(32, 32, kernel_size=(7,), stride=(1,))
#               )
#               (2): ELU(alpha=1.0)
#               (3): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#             )
#           )
#           (1): ResidualUnit(
#             (net): Sequential(
#               (0): ELU(alpha=1.0)
# ...

# %%
import torch

checkpoint = torch.load('/content/saved/testing/model_best.pth', weights_only=False)

# %%
checkpoint['config']['trainer']
# Out:
# {'log_step': 50, 'n_epochs': 11, 'epoch_len': 9000, 'resume_from': '/content/saved/gan_45k_baseline_extra/model_best.pth', 'device': 'auto', 'device_tensors': ['audio'], 'override': True, 'monitor': 'max test_STOI', 'save_period': 5, 'early_stop': '${trainer.n_epochs}', 'save_dir': '/content/saved', 'seed': 1, 'max_grad_norm': 1.0}
